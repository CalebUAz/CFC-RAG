# %% [markdown]
# # RAG System with Gemini Flash
#
# This notebook implements a Retrieval-Augmented Generation (RAG) system using:
# - Sermon transcripts from the dataset as knowledge base
# - Vector embeddings for semantic search
# - Google Gemini Flash for response generation
#
# Based on the structure from test.ipynb

# %%
# Import required libraries
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os

# LangChain imports
from langchain_core.documents import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores.faiss import FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# Load environment variables
load_dotenv()

# Verify API keys
if not os.environ.get("GOOGLE_API_KEY"):
    raise ValueError("GOOGLE_API_KEY is not set in the .env file.")

print("✅ Libraries imported and API key verified")
# Out:
# ✅ Libraries imported and API key verified

# %%
# Load the sermon dataset
df = pd.read_csv('dataset/sermons_zac.csv')

# Clean the data (similar to test.ipynb)
df = df.dropna(subset=['sermon'])
df['sermon'] = df['sermon'].apply(lambda x: x[6:] if x.lower().startswith('music ') else x)
if 'Unnamed: 0' in df.columns:
    df.drop(columns=['Unnamed: 0'], inplace=True)
df.reset_index(drop=True, inplace=True)

print(f"📊 Dataset loaded: {len(df)} sermons")
print(f"📝 Total words: {df['sermon'].str.split().str.len().sum():,}")
print("\nDataset columns:", df.columns.tolist())
print("\nSample titles:")
for i, title in enumerate(df['title'].head(3)):
    print(f"{i+1}. {title}")
# Out:
# 📊 Dataset loaded: 417 sermons
# 📝 Total words: 3,787,703
#
# Dataset columns: ['author', 'video_id', 'title', 'sermon']
#
# Sample titles:
# 1. Be Content with the Way God Made You — Zac Poonen — May 07, 2025
# 2. What Genuine Reverence for God Produces — Zac Poonen — May 04, 2025
# 3. The Presence of the Lord When We Break Bread — Zac Poonen — May 03, 2025

# %%
# Convert dataframe to LangChain documents
documents = []
for index, row in df.iterrows():
    doc = Document(
        page_content=row['sermon'],
        metadata={
            "title": row['title'],
            "author": row['author'],
            "video_id": row['video_id'],
            "doc_id": index
        }
    )
    documents.append(doc)

print(f"📄 Created {len(documents)} documents")
print(f"📏 Average document length: {np.mean([len(doc.page_content) for doc in documents]):.0f} characters")
# Out:
# 📄 Created 417 documents
# 📏 Average document length: 45677 characters

# %%
# Split documents into chunks for better retrieval
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=200,
    length_function=len,
    separators=["\n\n", "\n", " ", ""]
)

# Split the documents
split_docs = text_splitter.split_documents(documents)

print(f"🔪 Split into {len(split_docs)} chunks")
print(f"📏 Average chunk length: {np.mean([len(doc.page_content) for doc in split_docs]):.0f} characters")
# Out:
# 🔪 Split into 63420 chunks
# 📏 Average chunk length: 496 characters

# %%
# Initialize Gemini embeddings
embeddings = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001",
    google_api_key=os.environ.get("GOOGLE_API_KEY")
)

print("🔧 Gemini embeddings initialized")
print("⏳ Creating vector store... (this may take a few minutes)")
# Out:
# 🔧 Gemini embeddings initialized
# ⏳ Creating vector store... (this may take a few minutes)

# %%
# Create vector store with FAISS
# Assuming 'split_docs' is your list of all document chunks
# and 'embeddings' is your configured embedding model

# Create an initial vector store with the first batch
vectorstore = FAISS.from_documents(
    documents=split_docs[0:100],  # Start with the first 100 docs
    embedding=embeddings
)

# Loop through the rest of the documents in smaller batches
for i in range(100, len(split_docs), 100):
    # Add subsequent docs to the existing index
    vectorstore.add_documents(split_docs[i:i+100])
    print(f"Processed {i+100}/{len(split_docs)} documents")

print("✅ Vector store created successfully!")
print(f"🗂️ Indexed {len(split_docs)} document chunks")
# Out:
# Processed 200/63420 documents
# Processed 300/63420 documents
# Processed 400/63420 documents
# Processed 500/63420 documents
# Processed 600/63420 documents
# Processed 700/63420 documents
# Processed 800/63420 documents
# Processed 900/63420 documents
# Processed 1000/63420 documents
# Processed 1100/63420 documents
# Processed 1200/63420 documents
# Processed 1300/63420 documents
# Processed 1400/63420 documents
# Processed 1500/63420 documents
# Processed 1600/63420 documents
# Processed 1700/63420 documents
# Processed 1800/63420 documents
# Processed 1900/63420 documents
# Processed 2000/63420 documents
# Processed 2100/63420 documents
# Processed 2200/63420 documents
# Processed 2300/63420 documents
# Processed 2400/63420 documents
# Processed 2500/63420 documents
# Processed 2600/63420 documents
# Processed 2700/63420 documents
# Processed 2800/63420 documents
# Processed 2900/63420 documents
# Processed 3000/63420 documents
# Processed 3100/63420 documents
# Processed 3200/63420 documents
# Processed 3300/63420 documents
# Processed 3400/63420 documents
# Processed 3500/63420 documents
# Processed 3600/63420 documents
# Processed 3700/63420 documents
# Processed 3800/63420 documents
# Processed 3900/63420 documents
# Processed 4000/63420 documents
# Processed 4100/63420 documents
# Processed 4200/63420 documents
# Processed 4300/63420 documents
# Processed 4400/63420 documents
# Processed 4500/63420 documents
# Processed 4600/63420 documents
# Processed 4700/63420 documents
# Processed 4800/63420 documents
# Processed 4900/63420 documents
# Processed 5000/63420 documents
# Processed 5100/63420 documents
# Processed 5200/63420 documents
# Processed 5300/63420 documents
# Processed 5400/63420 documents
# Processed 5500/63420 documents
# Processed 5600/63420 documents
# Processed 5700/63420 documents
# Processed 5800/63420 documents
# Processed 5900/63420 documents
# Processed 6000/63420 documents
# Processed 6100/63420 documents
# Processed 6200/63420 documents
# Processed 6300/63420 documents
# Processed 6400/63420 documents
# Processed 6500/63420 documents
# Processed 6600/63420 documents
# Processed 6700/63420 documents
# Processed 6800/63420 documents
# Processed 6900/63420 documents
# Processed 7000/63420 documents
# Processed 7100/63420 documents
# Processed 7200/63420 documents
# Processed 7300/63420 documents
# Processed 7400/63420 documents
# Processed 7500/63420 documents
# Processed 7600/63420 documents
# Processed 7700/63420 documents
# Processed 7800/63420 documents
# Processed 7900/63420 documents
# Processed 8000/63420 documents
# Processed 8100/63420 documents
# Processed 8200/63420 documents
# Processed 8300/63420 documents
# Processed 8400/63420 documents
# Processed 8500/63420 documents
# Processed 8600/63420 documents
# Processed 8700/63420 documents
# Processed 8800/63420 documents
# Processed 8900/63420 documents
# Processed 9000/63420 documents
# Processed 9100/63420 documents
# Processed 9200/63420 documents
# Processed 9300/63420 documents
# Processed 9400/63420 documents
# Processed 9500/63420 documents
# Processed 9600/63420 documents
# Processed 9700/63420 documents
# Processed 9800/63420 documents
# Processed 9900/63420 documents
# Processed 10000/63420 documents
# Processed 10100/63420 documents
# Processed 10200/63420 documents
# Processed 10300/63420 documents
# Processed 10400/63420 documents
# Processed 10500/63420 documents
# Processed 10600/63420 documents
# Processed 10700/63420 documents
# Processed 10800/63420 documents
# Processed 10900/63420 documents
# Processed 11000/63420 documents
# Processed 11100/63420 documents
# Processed 11200/63420 documents
# Processed 11300/63420 documents
# Processed 11400/63420 documents
# Processed 11500/63420 documents
# Processed 11600/63420 documents
# Processed 11700/63420 documents
# Processed 11800/63420 documents
# Processed 11900/63420 documents
# Processed 12000/63420 documents
# Processed 12100/63420 documents
# Processed 12200/63420 documents
# Processed 12300/63420 documents
# Processed 12400/63420 documents
# Processed 12500/63420 documents
# Processed 12600/63420 documents
# Processed 12700/63420 documents
# Processed 12800/63420 documents
# Processed 12900/63420 documents
# Processed 13000/63420 documents
# Processed 13100/63420 documents
# Processed 13200/63420 documents
# Processed 13300/63420 documents
# Processed 13400/63420 documents
# Processed 13500/63420 documents
# Processed 13600/63420 documents
# Processed 13700/63420 documents
# Processed 13800/63420 documents
# Processed 13900/63420 documents
# Processed 14000/63420 documents
# Processed 14100/63420 documents
# Processed 14200/63420 documents
# Processed 14300/63420 documents
# Processed 14400/63420 documents
# Processed 14500/63420 documents
# Processed 14600/63420 documents
# Processed 14700/63420 documents
# Processed 14800/63420 documents
# Processed 14900/63420 documents
# Processed 15000/63420 documents
# Processed 15100/63420 documents
# Processed 15200/63420 documents
# Processed 15300/63420 documents
# Processed 15400/63420 documents
# Processed 15500/63420 documents
# Processed 15600/63420 documents
# Processed 15700/63420 documents
# Processed 15800/63420 documents
# Processed 15900/63420 documents
# Processed 16000/63420 documents
# Processed 16100/63420 documents
# Processed 16200/63420 documents
# Processed 16300/63420 documents
# Processed 16400/63420 documents
# Processed 16500/63420 documents
# Processed 16600/63420 documents
# Processed 16700/63420 documents
# Processed 16800/63420 documents
# Processed 16900/63420 documents
# Processed 17000/63420 documents
# Processed 17100/63420 documents
# Processed 17200/63420 documents
# Processed 17300/63420 documents
# Processed 17400/63420 documents
# Processed 17500/63420 documents
# Processed 17600/63420 documents
# Processed 17700/63420 documents
# Processed 17800/63420 documents
# Processed 17900/63420 documents
# Processed 18000/63420 documents
# Processed 18100/63420 documents
# Processed 18200/63420 documents
# Processed 18300/63420 documents
# Processed 18400/63420 documents
# Processed 18500/63420 documents
# Processed 18600/63420 documents
# Processed 18700/63420 documents
# Processed 18800/63420 documents
# Processed 18900/63420 documents
# Processed 19000/63420 documents
# Processed 19100/63420 documents
# Processed 19200/63420 documents
# Processed 19300/63420 documents
# Processed 19400/63420 documents
# Processed 19500/63420 documents
# Processed 19600/63420 documents
# Processed 19700/63420 documents
# Processed 19800/63420 documents
# Processed 19900/63420 documents
# Processed 20000/63420 documents
# Processed 20100/63420 documents
# Processed 20200/63420 documents
# Processed 20300/63420 documents
# Processed 20400/63420 documents
# Processed 20500/63420 documents
# Processed 20600/63420 documents
# Processed 20700/63420 documents
# Processed 20800/63420 documents
# Processed 20900/63420 documents
# Processed 21000/63420 documents
# Processed 21100/63420 documents
# Processed 21200/63420 documents
# Processed 21300/63420 documents
# Processed 21400/63420 documents
# Processed 21500/63420 documents
# Processed 21600/63420 documents
# Processed 21700/63420 documents
# Processed 21800/63420 documents
# Processed 21900/63420 documents
# Processed 22000/63420 documents
# Processed 22100/63420 documents
# Processed 22200/63420 documents
# Processed 22300/63420 documents
# Processed 22400/63420 documents
# Processed 22500/63420 documents
# Processed 22600/63420 documents
# Processed 22700/63420 documents
# Processed 22800/63420 documents
# Processed 22900/63420 documents
# Processed 23000/63420 documents
# Processed 23100/63420 documents
# Processed 23200/63420 documents
# Processed 23300/63420 documents
# Processed 23400/63420 documents
# Processed 23500/63420 documents
# Processed 23600/63420 documents
# Processed 23700/63420 documents
# Processed 23800/63420 documents
# Processed 23900/63420 documents
# Processed 24000/63420 documents
# Processed 24100/63420 documents
# Processed 24200/63420 documents
# Processed 24300/63420 documents
# Processed 24400/63420 documents
# Processed 24500/63420 documents
# Processed 24600/63420 documents
# Processed 24700/63420 documents
# Processed 24800/63420 documents
# Processed 24900/63420 documents
# Processed 25000/63420 documents
# Processed 25100/63420 documents
# Processed 25200/63420 documents
# Processed 25300/63420 documents
# Processed 25400/63420 documents
# Processed 25500/63420 documents
# Processed 25600/63420 documents
# Processed 25700/63420 documents
# Processed 25800/63420 documents
# Processed 25900/63420 documents
# Processed 26000/63420 documents
# Processed 26100/63420 documents
# Processed 26200/63420 documents
# Processed 26300/63420 documents
# Processed 26400/63420 documents
# Processed 26500/63420 documents
# Processed 26600/63420 documents
# Processed 26700/63420 documents
# Processed 26800/63420 documents
# Processed 26900/63420 documents
# Processed 27000/63420 documents
# Processed 27100/63420 documents
# Processed 27200/63420 documents
# Processed 27300/63420 documents
# Processed 27400/63420 documents
# Processed 27500/63420 documents
# Processed 27600/63420 documents
# Processed 27700/63420 documents
# Processed 27800/63420 documents
# Processed 27900/63420 documents
# Processed 28000/63420 documents
# Processed 28100/63420 documents
# Processed 28200/63420 documents
# Processed 28300/63420 documents
# Processed 28400/63420 documents
# Processed 28500/63420 documents
# Processed 28600/63420 documents
# Processed 28700/63420 documents
# Processed 28800/63420 documents
# Processed 28900/63420 documents
# Processed 29000/63420 documents
# Processed 29100/63420 documents
# Processed 29200/63420 documents
# Processed 29300/63420 documents
# Processed 29400/63420 documents
# Processed 29500/63420 documents
# Processed 29600/63420 documents
# Processed 29700/63420 documents
# Processed 29800/63420 documents
# Processed 29900/63420 documents
# Processed 30000/63420 documents
# Processed 30100/63420 documents
# Processed 30200/63420 documents
# Processed 30300/63420 documents
# Processed 30400/63420 documents
# Processed 30500/63420 documents
# Processed 30600/63420 documents
# Processed 30700/63420 documents
# Processed 30800/63420 documents
# Processed 30900/63420 documents
# Processed 31000/63420 documents
# Processed 31100/63420 documents
# Processed 31200/63420 documents
# Processed 31300/63420 documents
# Processed 31400/63420 documents
# Processed 31500/63420 documents
# Processed 31600/63420 documents
# Processed 31700/63420 documents
# Processed 31800/63420 documents
# Processed 31900/63420 documents
# Processed 32000/63420 documents
# Processed 32100/63420 documents
# Processed 32200/63420 documents
# Processed 32300/63420 documents
# Processed 32400/63420 documents
# Processed 32500/63420 documents
# Processed 32600/63420 documents
# Processed 32700/63420 documents
# Processed 32800/63420 documents
# Processed 32900/63420 documents
# Processed 33000/63420 documents
# Processed 33100/63420 documents
# Processed 33200/63420 documents
# Processed 33300/63420 documents
# Processed 33400/63420 documents
# Processed 33500/63420 documents
# Processed 33600/63420 documents
# Processed 33700/63420 documents
# Processed 33800/63420 documents
# Processed 33900/63420 documents
# Processed 34000/63420 documents
# Processed 34100/63420 documents
# Processed 34200/63420 documents
# Processed 34300/63420 documents
# Processed 34400/63420 documents
# Processed 34500/63420 documents
# Processed 34600/63420 documents
# Processed 34700/63420 documents
# Processed 34800/63420 documents
# Processed 34900/63420 documents
# Processed 35000/63420 documents
# Processed 35100/63420 documents
# Processed 35200/63420 documents
# Processed 35300/63420 documents
# Processed 35400/63420 documents
# Processed 35500/63420 documents
# Processed 35600/63420 documents
# Processed 35700/63420 documents
# Processed 35800/63420 documents
# Processed 35900/63420 documents
# Processed 36000/63420 documents
# Processed 36100/63420 documents
# Processed 36200/63420 documents
# Processed 36300/63420 documents
# Processed 36400/63420 documents
# Processed 36500/63420 documents
# Processed 36600/63420 documents
# Processed 36700/63420 documents
# Processed 36800/63420 documents
# Processed 36900/63420 documents
# Processed 37000/63420 documents
# Processed 37100/63420 documents
# Processed 37200/63420 documents
# Processed 37300/63420 documents
# Processed 37400/63420 documents
# Processed 37500/63420 documents
# Processed 37600/63420 documents
# Processed 37700/63420 documents
# Processed 37800/63420 documents
# Processed 37900/63420 documents
# Processed 38000/63420 documents
# Processed 38100/63420 documents
# Processed 38200/63420 documents
# Processed 38300/63420 documents
# Processed 38400/63420 documents
# Processed 38500/63420 documents
# Processed 38600/63420 documents
# Processed 38700/63420 documents
# Processed 38800/63420 documents
# Processed 38900/63420 documents
# Processed 39000/63420 documents
# Processed 39100/63420 documents
# Processed 39200/63420 documents
# Processed 39300/63420 documents
# Processed 39400/63420 documents
# Processed 39500/63420 documents
# Processed 39600/63420 documents
# Processed 39700/63420 documents
# Processed 39800/63420 documents
# Processed 39900/63420 documents
# Processed 40000/63420 documents
# Processed 40100/63420 documents
# Processed 40200/63420 documents
# Processed 40300/63420 documents
# Processed 40400/63420 documents
# Processed 40500/63420 documents
# Processed 40600/63420 documents
# Processed 40700/63420 documents
# Processed 40800/63420 documents
# Processed 40900/63420 documents
# Processed 41000/63420 documents
# Processed 41100/63420 documents
# Processed 41200/63420 documents
# Processed 41300/63420 documents
# Processed 41400/63420 documents
# Processed 41500/63420 documents
# Processed 41600/63420 documents
# Processed 41700/63420 documents
# Processed 41800/63420 documents
# Processed 41900/63420 documents
# Processed 42000/63420 documents
# Processed 42100/63420 documents
# Processed 42200/63420 documents
# Processed 42300/63420 documents
# Processed 42400/63420 documents
# Processed 42500/63420 documents
# Processed 42600/63420 documents
# Processed 42700/63420 documents
# Processed 42800/63420 documents
# Processed 42900/63420 documents
# Processed 43000/63420 documents
# Processed 43100/63420 documents
# Processed 43200/63420 documents
# Processed 43300/63420 documents
# Processed 43400/63420 documents
# Processed 43500/63420 documents
# Processed 43600/63420 documents
# Processed 43700/63420 documents
# Processed 43800/63420 documents
# Processed 43900/63420 documents
# Processed 44000/63420 documents
# Processed 44100/63420 documents
# Processed 44200/63420 documents
# Processed 44300/63420 documents
# Processed 44400/63420 documents
# Processed 44500/63420 documents
# Processed 44600/63420 documents
# Processed 44700/63420 documents
# Processed 44800/63420 documents
# Processed 44900/63420 documents
# Processed 45000/63420 documents
# Processed 45100/63420 documents
# Processed 45200/63420 documents
# Processed 45300/63420 documents
# Processed 45400/63420 documents
# Processed 45500/63420 documents
# Processed 45600/63420 documents
# Processed 45700/63420 documents
# Processed 45800/63420 documents
# Processed 45900/63420 documents
# Processed 46000/63420 documents
# Processed 46100/63420 documents
# Processed 46200/63420 documents
# Processed 46300/63420 documents
# Processed 46400/63420 documents
# Processed 46500/63420 documents
# Processed 46600/63420 documents
# Processed 46700/63420 documents
# Processed 46800/63420 documents
# Processed 46900/63420 documents
# Processed 47000/63420 documents
# Processed 47100/63420 documents
# Processed 47200/63420 documents
# Processed 47300/63420 documents
# Processed 47400/63420 documents
# Processed 47500/63420 documents
# Processed 47600/63420 documents
# Processed 47700/63420 documents
# Processed 47800/63420 documents
# Processed 47900/63420 documents
# Processed 48000/63420 documents
# Processed 48100/63420 documents
# Processed 48200/63420 documents
# Processed 48300/63420 documents
# Processed 48400/63420 documents
# Processed 48500/63420 documents
# Processed 48600/63420 documents
# Processed 48700/63420 documents
# Processed 48800/63420 documents
# Processed 48900/63420 documents
# Processed 49000/63420 documents
# Processed 49100/63420 documents
# Processed 49200/63420 documents
# Processed 49300/63420 documents
# Processed 49400/63420 documents
# Processed 49500/63420 documents
# Processed 49600/63420 documents
# Processed 49700/63420 documents
# Processed 49800/63420 documents
# Processed 49900/63420 documents
# Processed 50000/63420 documents
# Processed 50100/63420 documents
# Processed 50200/63420 documents
# Processed 50300/63420 documents
# Processed 50400/63420 documents
# Processed 50500/63420 documents
# Processed 50600/63420 documents
# Processed 50700/63420 documents
# Processed 50800/63420 documents
# Processed 50900/63420 documents
# Processed 51000/63420 documents
# Processed 51100/63420 documents
# Processed 51200/63420 documents
# Processed 51300/63420 documents
# Processed 51400/63420 documents
# Processed 51500/63420 documents
# Processed 51600/63420 documents
# Processed 51700/63420 documents
# Processed 51800/63420 documents
# Processed 51900/63420 documents
# Processed 52000/63420 documents
# Processed 52100/63420 documents
# Processed 52200/63420 documents
# Processed 52300/63420 documents
# Processed 52400/63420 documents
# Processed 52500/63420 documents
# Processed 52600/63420 documents
# Processed 52700/63420 documents
# Processed 52800/63420 documents
# Processed 52900/63420 documents
# Processed 53000/63420 documents
# Processed 53100/63420 documents
# Processed 53200/63420 documents
# Processed 53300/63420 documents
# Processed 53400/63420 documents
# Processed 53500/63420 documents
# Processed 53600/63420 documents
# Processed 53700/63420 documents
# Processed 53800/63420 documents
# Processed 53900/63420 documents
# Processed 54000/63420 documents
# Processed 54100/63420 documents
# Processed 54200/63420 documents
# Processed 54300/63420 documents
# Processed 54400/63420 documents
# Processed 54500/63420 documents
# Processed 54600/63420 documents
# Processed 54700/63420 documents
# Processed 54800/63420 documents
# Processed 54900/63420 documents
# Processed 55000/63420 documents
# Processed 55100/63420 documents
# Processed 55200/63420 documents
# Processed 55300/63420 documents
# Processed 55400/63420 documents
# Processed 55500/63420 documents
# Processed 55600/63420 documents
# Processed 55700/63420 documents
# Processed 55800/63420 documents
# Processed 55900/63420 documents
# Processed 56000/63420 documents
# Processed 56100/63420 documents
# Processed 56200/63420 documents
# Processed 56300/63420 documents
# Processed 56400/63420 documents
# Processed 56500/63420 documents
# Processed 56600/63420 documents
# Processed 56700/63420 documents
# Processed 56800/63420 documents
# Processed 56900/63420 documents
# Processed 57000/63420 documents
# Processed 57100/63420 documents
# Processed 57200/63420 documents
# Processed 57300/63420 documents
# Processed 57400/63420 documents
# Processed 57500/63420 documents
# Processed 57600/63420 documents
# Processed 57700/63420 documents
# Processed 57800/63420 documents
# Processed 57900/63420 documents
# Processed 58000/63420 documents
# Processed 58100/63420 documents
# Processed 58200/63420 documents
# Processed 58300/63420 documents
# Processed 58400/63420 documents
# Processed 58500/63420 documents
# Processed 58600/63420 documents
# Processed 58700/63420 documents
# Processed 58800/63420 documents
# Processed 58900/63420 documents
# Processed 59000/63420 documents
# Processed 59100/63420 documents
# Processed 59200/63420 documents
# Processed 59300/63420 documents
# Processed 59400/63420 documents
# Processed 59500/63420 documents
# Processed 59600/63420 documents
# Processed 59700/63420 documents
# Processed 59800/63420 documents
# Processed 59900/63420 documents
# Processed 60000/63420 documents
# Processed 60100/63420 documents
# Processed 60200/63420 documents
# Processed 60300/63420 documents
# Processed 60400/63420 documents
# Processed 60500/63420 documents
# Processed 60600/63420 documents
# Processed 60700/63420 documents
# Processed 60800/63420 documents
# Processed 60900/63420 documents
# Processed 61000/63420 documents
# Processed 61100/63420 documents
# Processed 61200/63420 documents
# Processed 61300/63420 documents
# Processed 61400/63420 documents
# Processed 61500/63420 documents
# Processed 61600/63420 documents
# Processed 61700/63420 documents
# Processed 61800/63420 documents
# Processed 61900/63420 documents
# Processed 62000/63420 documents
# Processed 62100/63420 documents
# Processed 62200/63420 documents
# Processed 62300/63420 documents
# Processed 62400/63420 documents
# Processed 62500/63420 documents
# Processed 62600/63420 documents
# Processed 62700/63420 documents
# Processed 62800/63420 documents
# Processed 62900/63420 documents
# Processed 63000/63420 documents
# Processed 63100/63420 documents
# Processed 63200/63420 documents
# Processed 63300/63420 documents
# Processed 63400/63420 documents
# Processed 63500/63420 documents
# ✅ Vector store created successfully!
# 🗂️ Indexed 63420 document chunks

# %%
# Save the vector store to disk
vectorstore.save_local("vectorstore/sermons_vectorstore")
print("💾 Vector store saved to disk as 'sermons_vectorstore'")
# Out:
# 💾 Vector store saved to disk as 'sermons_vectorstore'

# %%
# Load the vector store from disk
vectorstore_loaded = FAISS.load_local("vectorstore/sermons_vectorstore", embeddings,
allow_dangerous_deserialization=True)

# %%
# Initialize Gemini Flash model
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    temperature=0.0,
    google_api_key=os.environ.get("GOOGLE_API_KEY")
)

print("🤖 Gemini Flash model initialized")
# Out:
# 🤖 Gemini Flash model initialized

# %%
# Create retriever
retriever = vectorstore_loaded.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}  # Retrieve top 5 most similar chunks
)

print("🔍 Retriever configured to return top 5 similar chunks")
# Out:
# 🔍 Retriever configured to return top 5 similar chunks

# %%
# Define the RAG prompt template
rag_prompt = ChatPromptTemplate.from_template("""
You are a helpful assistant that answers questions based on sermon content from Zac Poonen.

Use the following context from the sermons to answer the question. If the context doesn't contain 
enough information to answer the question, say so honestly.

Context from sermons:
{context}

Question: {question}

Answer: Provide a thoughtful response based on the sermon content. Include relevant Bible verses 
or spiritual insights when mentioned in the context. Be helpful and encouraging in your tone.
""")

print("📝 RAG prompt template created")
# Out:
# 📝 RAG prompt template created

# %%
# Helper function to format retrieved documents
def format_docs(docs):
    formatted_context = []
    for i, doc in enumerate(docs, 1):
        title = doc.metadata.get('title', 'Unknown Title')
        content = doc.page_content[:500] + "..." if len(doc.page_content) > 500 else doc.page_content
        formatted_context.append(f"Sermon {i}: {title}\n{content}\n")
    return "\n".join(formatted_context)

print("🔧 Document formatting function created")
# Out:
# 🔧 Document formatting function created

# %%
# Create the RAG chain
rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | rag_prompt
    | llm
    | StrOutputParser()
)

print("⛓️ RAG chain created successfully!")
print("🎉 System ready for queries!")
# Out:
# ⛓️ RAG chain created successfully!
# 🎉 System ready for queries!

# %% [markdown]
# ## Query Interface
#
# Now you can ask questions about the sermon content!

# %%
# Function to query the RAG system
def query_sermons(question: str, show_sources: bool = True):
    """
    Query the RAG system with a question about the sermons.
    
    Args:
        question (str): The question to ask
        show_sources (bool): Whether to show the source documents
    
    Returns:
        str: The generated answer
    """
    print(f"❓ Question: {question}")
    print("🔍 Searching for relevant content...")
    
    # Get relevant documents
    relevant_docs = retriever.get_relevant_documents(question)
    
    if show_sources:
        print("\n📚 Sources found:")
        for i, doc in enumerate(relevant_docs, 1):
            title = doc.metadata.get('title', 'Unknown Title')
            print(f"{i}. {title}")
    
    # Generate answer
    print("\n🤖 Generating answer...")
    answer = rag_chain.invoke(question)
    
    print("\n💬 Answer:")
    print(answer)
    
    return answer

print("✅ Query function ready!")
# Out:
# ✅ Query function ready!

# %% [markdown]
# ## Example Queries
#
# Try asking questions about the sermon content:

# %%
# Example query 1: About contentment
query_sermons("What does the Bible teach about contentment?")
# Out:
# ❓ Question: What does the Bible teach about contentment?
# 🔍 Searching for relevant content...
#
# 📚 Sources found:
# 1. 6. Never Doubt Christ's Love for You — Zac Poonen — August 25, 2024
# 2. Be Content with the Way God Made You — Zac Poonen — May 07, 2025
# 3. 6. Contentment -- Zac Poonen -- March 1, 2009
# 4. Godliness with Contentment Brings Great Spiritual Profit -- Zac Poonen -- October 2, 2024
# 5. 6. Never Doubt Christ's Love for You — Zac Poonen — August 25, 2024
#
# 🤖 Generating answer...
#
# 💬 Answer:
# Based on Zac Poonen's sermons, the Bible teaches that contentment is a vital aspect of godliness.  Several sermons emphasize Hebrews 13:5, which encourages us to "make sure your character is free from the love of money; be content with what you have."  This doesn't mean we shouldn't strive for improvement in our circumstances (like seeking a better job if the cost of living increases), but rather that our hearts should not be consumed by a desire for more.  True contentment comes from recognizing God's provision and being thankful for what He has given, regardless of the amount.
#
# Poonen shares a personal testimony of 56 years of marriage with his wife, where they have consistently been content with their provision, never once asking God for more.  This contentment, he testifies, has brought them great happiness.  He highlights that this contentment is not passive resignation, but an active choice to trust in God's provision and care.  He connects contentment to spiritual growth, stating that without a right attitude towards money and material things, true spirituality is impossible; one might be religious but not truly spiritual.  Contentment, therefore, is presented as essential for a deep and meaningful relationship with God.  The sermons emphasize that Godliness accompanied with contentment is great gain (1 Timothy 6:6, implied).  Ultimately, contentment is presented as a key to experiencing God's peace and blessing in all circumstances.
# 'Based on Zac Poonen\'s sermons, the Bible teaches that contentment is a vital aspect of godliness.  Several sermons emphasize Hebrews 13:5, which encourages us to "make sure your character is free from the love of money; be content with what you have."  This doesn\'t mean we shouldn\'t strive for improvement in our circumstances (like seeking a better job if the cost of living increases), but rather that our hearts should not be consumed by a desire for more.  True contentment comes from recognizing God\'s provision and being thankful for what He has given, regardless of the amount.\n\nPoonen shares a personal testimony of 56 years of marriage with his wife, where they have consistently been content with their provision, never once asking God for more.  This contentment, he testifies, has brought them great happiness.  He highlights that this contentment is not passive resignation, but an active choice to trust in God\'s provision and care.  He connects contentment to spiritual growth, stating that without a right attitude towards money and material things, true spirituality is impossible; one might be religious but not truly spiritual.  Contentment, therefore, is presented as essential for a deep and meaningful relationship with God.  The sermons emphasize that Godliness accompanied with contentment is great gain (1 Timothy 6:6, implied).  Ultimately, contentment is presented as a key to experiencing God\'s peace and blessing in all circumstances.'

# %%
query_sermons("What age does Zac recommend men and women to consider marriage?")
# Out:
# ❓ Question: What age does Zac recommend men and women to consider marriage?
# 🔍 Searching for relevant content...
#
# 📚 Sources found:
# 1. RLCF Men's Conference 2025 Q&A Session #2 — Zac Poonen — April 19, 2025
# 2. Global Online Meeting Q&A -- Zac Poonen -- March 13, 2021
# 3. Questions & Answers - Zac Poonen - September 13, 2014
# 4. 5. Seeing Jesus Clearly in the Bible — Zac Poonen — August 25, 2024
# 5. Questions & Answers - Zac Poonen - September 13, 2014
#
# 🤖 Generating answer...
#
# 💬 Answer:
# Based on Zac Poonen's sermons, there's no single recommended age for marriage.  He emphasizes that the decision is deeply personal and should be guided by prayer and surrender to God's will.
#
# Several points emerge from his counsel:
#
# * **Spiritual Readiness:**  He highlights the importance of spiritual maturity before marriage.  In Sermon 5, he advises against marrying too young, explaining that it can hinder the dedicated study of scripture, which is crucial for a strong spiritual life.  He personally married at 28 1/2, after being converted at 19 1/2, suggesting a period of spiritual growth before marriage.
#
# * **Financial Stability:** Sermon 3 mentions 1 Corinthians 7:9 ("better to marry than to burn"), suggesting that being old enough and financially capable of supporting a family is a factor to consider.  This is presented as one way to discern God's timing, not as a strict rule.
#
# * **Avoiding Immorality:**  Sermon 3 also references 1 Corinthians 7:2 ("let every man have his own wife"), connecting marriage to avoiding fornication and immorality. This implies that if someone is struggling with temptation, marriage might be a path to consider, but only with careful prayer and discernment.
#
# * **Personal Discernment through Prayer:**  In Sermon 2, he shares his own experience of surrendering to God's will regarding marriage at age 24, praying for guidance on whether to remain single or marry.  He emphasizes that in most cases, God's will is marriage, but the timing and the right person are matters of prayer and seeking God's leading.
#
# * **Caution and Humility:** Sermon 4 reveals Zac's own hesitancy to give definitive advice on marriage, emphasizing that he cannot know what is best for another person. He encourages seeking God's guidance through prayer rather than relying solely on another's opinion.
#
# In summary, Zac Poonen doesn't prescribe a specific age for marriage.  Instead, he stresses the importance of spiritual maturity, financial stability, prayerful discernment, and seeking God's will in this significant life decision.  He encourages individuals to consider their own spiritual readiness, potential temptations, and financial capacity while seeking God's guidance through prayer.
# 'Based on Zac Poonen\'s sermons, there\'s no single recommended age for marriage.  He emphasizes that the decision is deeply personal and should be guided by prayer and surrender to God\'s will.\n\nSeveral points emerge from his counsel:\n\n* **Spiritual Readiness:**  He highlights the importance of spiritual maturity before marriage.  In Sermon 5, he advises against marrying too young, explaining that it can hinder the dedicated study of scripture, which is crucial for a strong spiritual life.  He personally married at 28 1/2, after being converted at 19 1/2, suggesting a period of spiritual growth before marriage.\n\n* **Financial Stability:** Sermon 3 mentions 1 Corinthians 7:9 ("better to marry than to burn"), suggesting that being old enough and financially capable of supporting a family is a factor to consider.  This is presented as one way to discern God\'s timing, not as a strict rule.\n\n* **Avoiding Immorality:**  Sermon 3 also references 1 Corinthians 7:2 ("let every man have his own wife"), connecting marriage to avoiding fornication and immorality. This implies that if someone is struggling with temptation, marriage might be a path to consider, but only with careful prayer and discernment.\n\n* **Personal Discernment through Prayer:**  In Sermon 2, he shares his own experience of surrendering to God\'s will regarding marriage at age 24, praying for guidance on whether to remain single or marry.  He emphasizes that in most cases, God\'s will is marriage, but the timing and the right person are matters of prayer and seeking God\'s leading.\n\n* **Caution and Humility:** Sermon 4 reveals Zac\'s own hesitancy to give definitive advice on marriage, emphasizing that he cannot know what is best for another person. He encourages seeking God\'s guidance through prayer rather than relying solely on another\'s opinion.\n\nIn summary, Zac Poonen doesn\'t prescribe a specific age for marriage.  Instead, he stresses the importance of spiritual maturity, financial stability, prayerful discernment, and seeking God\'s will in this significant life decision.  He encourages individuals to consider their own spiritual readiness, potential temptations, and financial capacity while seeking God\'s guidance through prayer.'

# %%
# Example query 2: About marriage and family
query_sermons("What guidance does the Bible provide for marriage and family relationships?")

# %%
# Example query 3: About spiritual gifts
query_sermons("How should Christians view their spiritual gifts and talents?")

# %%
# Interactive query cell - modify this to ask your own questions
your_question = "What does Zac Poonen teach about godliness?"
query_sermons(your_question)

# %% [markdown]
# ## Advanced Features
#
# Additional functionality for the RAG system:

# %%
# Function to search for specific topics
def search_topic(topic: str, num_results: int = 3):
    """
    Search for sermons containing a specific topic.
    
    Args:
        topic (str): The topic to search for
        num_results (int): Number of results to return
    
    Returns:
        list: List of relevant documents
    """
    print(f"🔍 Searching for topic: '{topic}'")
    
    # Search for relevant documents
    docs = vectorstore.similarity_search(topic, k=num_results)
    
    print(f"\n📋 Found {len(docs)} relevant sermon excerpts:")
    
    for i, doc in enumerate(docs, 1):
        title = doc.metadata.get('title', 'Unknown Title')
        preview = doc.page_content[:200] + "..." if len(doc.page_content) > 200 else doc.page_content
        print(f"\n{i}. **{title}**")
        print(f"   {preview}")
    
    return docs

print("🔍 Topic search function ready!")

# %%
# Example topic search
search_topic("faith and trust in God")

# %%
# Function to get sermon statistics
def get_sermon_stats():
    """
    Display statistics about the sermon dataset.
    """
    print("📊 Sermon Dataset Statistics:")
    print(f"   • Total sermons: {len(df)}")
    print(f"   • Total words: {df['sermon'].str.split().str.len().sum():,}")
    print(f"   • Average words per sermon: {df['sermon'].str.split().str.len().mean():.0f}")
    print(f"   • Document chunks in vector store: {len(split_docs)}")
    
    # Count Q&A sessions
    qa_count = df['title'].str.contains('Questions & Answers|Q&A', case=False, na=False).sum()
    print(f"   • Q&A sessions: {qa_count}")
    print(f"   • Regular sermons: {len(df) - qa_count}")
    
    print(f"\n📅 Date range: Based on titles, sermons span multiple years")
    print(f"👨‍🏫 Primary speaker: {df['author'].iloc[0]}")

get_sermon_stats()

# %% [markdown]
# ## System Information
#
# This RAG system provides:
#
# 1. **Knowledge Base**: 400+ sermon transcripts from Zac Poonen
# 2. **Embeddings**: Google's embedding-001 model for semantic search
# 3. **Vector Store**: FAISS for efficient similarity search
# 4. **Generation**: Gemini Flash for natural language responses
# 5. **Retrieval**: Top-5 most relevant sermon excerpts for each query
#
# ### Usage Tips:
# - Ask specific questions about biblical topics, spiritual growth, or Christian living
# - The system will find relevant sermon content and provide contextual answers
# - Responses include biblical references and spiritual insights from the sermons
# - Use the `search_topic()` function to explore specific themes
#
# ### Example Questions:
# - "How can I grow in faith?"
# - "What does the Bible say about forgiveness?"
# - "How should Christians handle trials and difficulties?"
# - "What is the role of prayer in a believer's life?"
